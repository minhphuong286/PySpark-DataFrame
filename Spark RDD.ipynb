# %% [markdown]
# Ví dụ 1:

# %%
# !pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 204.2MB 63kB/s
# ...
#      |████████████████████████████████| 204kB 34.4MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.0.1-py2.py3-none-any.whl size=204612242 sha256=8f7e1cf8540b1386477b9cfc772071b7a4e655ba6e796a11915b174b3b0cfd61
#   Stored in directory: /root/.cache/pip/wheels/5e/bd/07/031766ca628adec8435bb40f0bd83bb676ce65ff4007f8e73f
# Successfully built pyspark
# ...

# %%
from pyspark import SparkContext, SparkConf

# %%
conf = SparkConf().setMaster("local").setAppName("word counting")
sc = SparkContext.getOrCreate(conf=conf)

# %%
data = [('a', 5), ('b', 2), ('1', 4), ('d', 3), ('2', 1)]
distData = sc.parallelize(data)
distData = distData.sortBy(lambda x: x[0])
distData.collect()
# Out:
# [('1', 4), ('2', 1), ('a', 5), ('b', 2), ('d', 3)]

# %%
distData = distData.sortBy(lambda x: x[1])
distData.collect()
# Out:
# [('2', 1), ('b', 2), ('d', 3), ('1', 4), ('a', 5)]

# %% [markdown]
# Ví dụ 2:

# %%
text = sc.textFile("/content/drive/MyDrive/Colab Notebooks/source2.txt")
print(text.collect())

text = text.flatMap(lambda x: (x.split(" ")))
print(text.collect())

max = text.max()
print(max)
# Out:
# ['1 3 9 5 2 4 10 8']
# ['1', '3', '9', '5', '2', '4', '10', '8']
# 9
